# %% [markdown]
# Import what you need

# %%
from automation.templates.bestiary import Bestiary
from automation.simulator.deck import Deck, Encounter

# %% [markdown]
# Use the raw dict grab various combatants

# %%
b = Bestiary(input_files="06_Bestiary_SAMPLE.yaml").raw_data
c1 = b["Clubs1"]
c1.update(dict(Name="🔸", id="A"))
c2 = b["Clubs1"]
c2.update(dict(Name="🔹", id="B"))
s = b["Spider Queen"]
s.update(dict(Name="💎", id="C"))

# %% [markdown]
# As example:

# %%
from pprint import pprint

pprint(c1)
# Out:
# {'AP': 2,
#  'Attribs': {'AGL': 1, 'GUT': 1, 'INT': -1, 'STR': 1, 'VIT': 1},
#  'HP': 7,
#  'Level': 1,
#  'Name': '🔹',
#  'PP': 2,
#  'Powers': ['Attack, Weapon',
#             'Attack, Charge',
#             'Attack, Dual-Wield',
#             'Momentum',
#             'Dumb',
#             'Sweep',
#             'Drown'],
#  'Primary_Skill': 'Brute',
#  'Pronouns': 'He/Him',
#  'Role': 'Defender',
#  'Skills': {'Athletics': 1,
#             'Brute': 1,
#             'Finesse': 1,
#             'Investigation': -1,
#             'Knowledge': -1,
#             'Stealth': 1},
#  'Type': 'PC',
#  'id': 'B'}

# %% [markdown]
# Run encounter:

# %%
e = Encounter(PCs=[c1, c2], Enemies=[s])
e.sim_round()
# Out:
# [2023-01-15 19:33:09,609][INFO]: 💎 start turn
# [2023-01-15 19:33:09,609][INFO]: 💎 used 0/6 PP with Sear
# [2023-01-15 19:33:09,610][INFO]: Drew [♥️ Q] vs ♠️ 4 with TR 0: Miss
# [2023-01-15 19:33:09,610][INFO]: 🔹 is Burned 🔥: 1
# [2023-01-15 19:33:09,610][INFO]: 💎 used 0/6 PP with Attack, Mystic
# [2023-01-15 19:33:09,610][INFO]: Drew [♥️ A] vs ♠️ 4 with TR 4: Hit
# [2023-01-15 19:33:09,611][INFO]: 💎 wounded 🔹 by 1: AP 1/2, HP 7/7
# [2023-01-15 19:33:09,611][INFO]: 🔹 start turn
# [2023-01-15 19:33:09,611][INFO]: 🔹 used 0/2 PP with Attack, Weapon
# [2023-01-15 19:33:09,612][INFO]: Drew [♥️ 7] vs ♠️ K with TR 3: Miss
# [2023-01-15 19:33:09,612][INFO]: Drew [♥️ 3] vs ♠️ 4 with TR 4: Hit
# [2023-01-15 19:33:09,613][INFO]: 🔹 used Minor Action to stop burning.
# [2023-01-15 19:33:09,613][INFO]: 🔹 start turn
# [2023-01-15 19:33:09,613][INFO]: 🔹 used 1/2 PP with Attack, Charge
# [2023-01-15 19:33:09,614][INFO]: Drew [♥️ T] vs ♠️ K with TR 3: Hit
# [2023-01-15 19:33:09,614][INFO]: 🔹 wounded 💎 by 2: AP 0/2, HP 8/8
# [2023-01-15 19:33:09,614][INFO]: 🔹 used 0/1 PP with Attack, Dual-Wield
# [2023-01-15 19:33:09,614][INFO]: Drew [♠️ 8, ♥️ 4, ♥️ A] vs ♠️ K with TR 3 at Lower Hand 3: Miss
